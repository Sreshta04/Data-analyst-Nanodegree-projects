# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer
import pandas as pd
import requests
import io
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
#TWITTER ARCHIVE

# %%
df=pd.read_csv('twitter-archive-enhanced.csv')

# %%
df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df.tweet_id.values
len(tweet_ids)
# Out:
# 2356

# %%
#JSON RETWEET AND LIKE COUNT

# %%
#load the json data and store it in a list
data = []
with open('tweet-json.txt') as f:    
        for line in f:         
             data.append(json.loads(line))
#create dataframe from json data
df_api = pd.DataFrame(data)
#select columns of interest
columns_of_interest = ['id', 'retweet_count', 'favorite_count']
tweet_df = df_api[columns_of_interest]

# %%
tweet_df.head()
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %%
#IMAGE PREDICTIONS

# %%
r=requests.get('https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv', auth=('user', 'pass')).content

# %%
images_df = pd.read_csv(io.StringIO(r.decode('utf-8')),delimiter='\t')

# %%
images_df.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
len(df), len(tweet_df), len(tweet_df)
# Out:
# (2356, 2354, 2354)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# id                2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %%
images_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
#making copies from original dataframes
df_clean=df.copy()
tweetdf_clean=tweet_df.copy()
imagesdf_clean=images_df.copy()

# %%
df_clean.iloc[0]
# Out:
# tweet_id                                                     892420643555336193
# in_reply_to_status_id                                                       NaN
# in_reply_to_user_id                                                         NaN
# timestamp                                             2017-08-01 16:23:56 +0000
# source                        <a href="http://twitter.com/download/iphone" r...
# text                          This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                         NaN
# retweeted_status_user_id                                                    NaN
# retweeted_status_timestamp                                                  NaN
# expanded_urls                 https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                             13
# rating_denominator                                                           10
# ...

# %% [markdown]
# ***Quality Issues***
#
# 1) Only tweets with no retweets are in the dataframe. Drop the ones without the retweet_status_id being NaN
#
# 2) There shouldn't be duplicates in all three dataframes
#
# 3) Correct the format of timestamp column
#
# 4) Dog names need to be actual dog names and remove any words which might not be dog names
#
# 5) Capitalize first letter of name
#
# 6) Denominator rating should be always 10
#
# 7) Numerator rating shouldn't have outliers
#
# 8) Delete columns which are not important for the study

# %%
#1) Only tweets with no retweets are in the dataframe. 
#Drop the ones without the retweet_status_id being NaN

# %%
df_clean=df_clean[df_clean['retweeted_status_id'].isnull()]
df_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
#2) There shouldn't be duplicate tweet_id entries

# %%
df_clean.drop_duplicates(inplace=True)
tweetdf_clean.drop_duplicates(inplace=True)
imagesdf_clean.drop_duplicates(inplace=True)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2175 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2175 non-null object
# source                        2175 non-null object
# text                          2175 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2117 non-null object
# rating_numerator              2175 non-null int64
# rating_denominator            2175 non-null int64
# name                          2175 non-null object
# doggo                         2175 non-null object
# floofer                       2175 non-null object
# pupper                        2175 non-null object
# ...

# %%
tweetdf_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# id                2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 73.6 KB

# %%
imagesdf_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 168.2+ KB

# %%
#3) Correct the format of timestamp column

# %%
df_clean['timestamp']=pd.to_datetime(df_clean['timestamp'])

# %%
#Test
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2175 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2175 non-null datetime64[ns]
# source                        2175 non-null object
# text                          2175 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2117 non-null object
# rating_numerator              2175 non-null int64
# rating_denominator            2175 non-null int64
# name                          2175 non-null object
# doggo                         2175 non-null object
# floofer                       2175 non-null object
# pupper                        2175 non-null object
# ...

# %%
#4) Dog names need to be actual dog names 
# and remove any words which might not be dog names

# %%
df_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#             timestamp                                             source  \
# 0 2017-08-01 16:23:56  <a href="http://twitter.com/download/iphone" r...
# 1 2017-08-01 00:17:27  <a href="http://twitter.com/download/iphone" r...
# 2 2017-07-31 00:18:03  <a href="http://twitter.com/download/iphone" r...
# 3 2017-07-30 15:58:51  <a href="http://twitter.com/download/iphone" r...
# 4 2017-07-29 16:00:24  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# ...

# %%
df_clean.name.value_counts()
# Out:
# None         680
# a             55
# Lucy          11
# Charlie       11
# Oliver        10
# Cooper        10
# Tucker         9
# Penny          9
# Lola           8
# the            8
# Sadie          8
# Winston        8
# Toby           7
# Daisy          7
# Jax            6
# Koda           6
# Oscar          6
# Bo             6
# an             6
# Bella          6
# Stanley        6
# Bailey         6
# Milo           5
# Scout          5
# Bentley        5
# Leo            5
# Buddy          5
# Rusty          5
# Chester        5
# Dave           5
#             ...
# Mingus         1
# Deacon         1
# Pipsy          1
# Lulu           1
# Sephie         1
# Grey           1
# Duddles        1
# Blanket        1
# Bluebert       1
# Kanu           1
# Vixen          1
# Ralphie        1
# Todo           1
# Kuyu           1
# Lenox          1
# Patch          1
# Asher          1
# Charleson      1
# Ben            1
# Coopson        1
# Dante          1
# ...

# %%
#Replacing 'a','the' and 'an' with 'None'

# %%
df_clean['name'].replace({'a':'None','the':'None','an':'None'},inplace=True)

# %%
#Test
df_clean.name.value_counts()
# Out:
# None         749
# Lucy          11
# Charlie       11
# Oliver        10
# Cooper        10
# Penny          9
# Tucker         9
# Sadie          8
# Lola           8
# Winston        8
# Toby           7
# Daisy          7
# Stanley        6
# Bella          6
# Bo             6
# Koda           6
# Oscar          6
# Bailey         6
# Jax            6
# Rusty          5
# Louis          5
# Bentley        5
# Leo            5
# Milo           5
# Buddy          5
# Scout          5
# Dave           5
# Chester        5
# Cassie         4
# Derek          4
#             ...
# Mingus         1
# Deacon         1
# Pipsy          1
# Lulu           1
# Sephie         1
# Grey           1
# Duddles        1
# Blanket        1
# Bluebert       1
# Kanu           1
# Vixen          1
# Ralphie        1
# Todo           1
# Kuyu           1
# Lenox          1
# Patch          1
# Asher          1
# Charleson      1
# Ben            1
# Coopson        1
# Dante          1
# ...

# %%
#5) Capitalize first letter of name

# %%
df_clean['name']=df_clean.name.str.capitalize()

# %%
#Test
df_clean.name.str.islower().sum()
# Out:
# 0

# %%
#6) Denominator rating should be always 10

# %%
df_clean[df_clean.rating_denominator!=10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# 1254  710658690886586372                    NaN                  NaN
# 1274  709198395643068416                    NaN                  NaN
# 1351  704054845121142784                    NaN                  NaN
# ...

# %%
df_clean.rating_denominator=10

# %%
#Test
df_clean.loc[516]['rating_denominator']!=10
# Out:
# False

# %%
#7) Numerator rating shouldn't have outliers

# %%
df_clean[df_clean.rating_numerator>20]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 290   838150277551247360           8.381455e+17         2.195506e+07
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 695   786709082849828864                    NaN                  NaN
# 763   778027034220126208                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 979   749981277374128128                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# ...

# %%
#Filling these outliers with the average of the rating numerator which is 13
df_clean['rating_numerator'].mean()
# Out:
# 13.215172413793104

# %%
df_clean.loc[df_clean.rating_numerator>20, ['rating_numerator']]=13

# %%
#Test
df_clean.loc[df_clean.rating_numerator>20, ['rating_numerator']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 1 columns):
# rating_numerator    0 non-null int64
# dtypes: int64(1)
# memory usage: 0.0 bytes

# %%
#8) Delete columns which are not important for the study

# %%
df_clean.drop(['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp'],axis=1,inplace=True)

# %%
#Test
df_clean.head()
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
# 3  891689557279858688 2017-07-30 15:58:51
# 4  891327558926688256 2017-07-29 16:00:24
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %% [markdown]
# **Tidiness issues**
#
# 1) Merge the four columns to one for the stage the dog is in
#
# 2) Change the column in tweetdf_clean 'id' to 'tweet_id' and merge all dataframes into a master dataframe

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2175 non-null int64
# timestamp             2175 non-null datetime64[ns]
# source                2175 non-null object
# text                  2175 non-null object
# expanded_urls         2117 non-null object
# rating_numerator      2175 non-null int64
# rating_denominator    2175 non-null int64
# name                  2175 non-null object
# doggo                 2175 non-null object
# floofer               2175 non-null object
# pupper                2175 non-null object
# puppo                 2175 non-null object
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 300.9+ KB

# %%
#1) Merge the four columns to one for the stage the dog is in
df_clean.loc[df_clean['doggo'] == 'doggo', 'dog_stage'] = 'doggo'
df_clean.loc[df_clean['floofer'] == 'floofer', 'dog_stage'] = 'floofer'
df_clean.loc[df_clean['pupper'] == 'pupper', 'dog_stage'] = 'pupper'
df_clean.loc[df_clean['puppo'] == 'puppo', 'dog_stage'] = 'puppo'

# %%
#Test
df_clean.head(10)
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
# 3  891689557279858688 2017-07-30 15:58:51
# 4  891327558926688256 2017-07-29 16:00:24
# 5  891087950875897856 2017-07-29 00:08:17
# 6  890971913173991426 2017-07-28 16:27:12
# 7  890729181411237888 2017-07-28 00:22:40
# 8  890609185150312448 2017-07-27 16:25:51
# 9  890240255349198849 2017-07-26 15:59:51
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
# 5  <a href="http://twitter.com/download/iphone" r...
# 6  <a href="http://twitter.com/download/iphone" r...
# 7  <a href="http://twitter.com/download/iphone" r...
# ...

# %%
#Dropping columns doggo,floofer,pupper and puppo
df_clean.drop(columns={'doggo','floofer','pupper','puppo'},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-171-bb2393ccee44> in <module>()
#       1 #Dropping columns doggo,floofer,pupper and poppu
# ----> 2 df_clean.drop(columns={'doggo','floofer','pupper','puppo'},inplace=True)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
# ...

# %%
#Test
df_clean.head(1)
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
#
#    rating_denominator     name dog_stage
# 0                  10  Phineas       NaN

# %%
tweetdf_clean.head(1)
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467

# %%
imagesdf_clean.head(1)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
#
#    img_num                      p1   p1_conf  p1_dog      p2   p2_conf  \
# 0        1  Welsh_springer_spaniel  0.465074    True  collie  0.156665
#
#    p2_dog                 p3   p3_conf  p3_dog
# 0    True  Shetland_sheepdog  0.061428    True

# %%
#2) Change the column in tweetdf_clean 'id' to 'tweet_id' 
#and merge all dataframes into a master dataframe

# %%
#Changing column name
tweetdf_clean.rename(columns={'id':'tweet_id'},inplace=True)

# %%
#Test
tweetdf_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 73.6 KB

# %%
#Merging dataframe into master df

# %%
#Checking number of values of tweet_id in both tweetdf_clean and df_clean
df_clean.tweet_id.count(), tweetdf_clean.tweet_id.count()
# Out:
# (2175, 2354)

# %%
dfmerge1=pd.merge(df_clean,tweetdf_clean,on='tweet_id',how='inner')

# %%
#Test
dfmerge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2174
# Data columns (total 11 columns):
# tweet_id              2175 non-null int64
# timestamp             2175 non-null datetime64[ns]
# source                2175 non-null object
# text                  2175 non-null object
# expanded_urls         2117 non-null object
# rating_numerator      2175 non-null int64
# rating_denominator    2175 non-null int64
# name                  2175 non-null object
# dog_stage             344 non-null object
# retweet_count         2175 non-null int64
# favorite_count        2175 non-null int64
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 203.9+ KB

# %%
#Checking and dropping duplicates in new dataframe
dfmerge1.drop_duplicates()
# Out:
#                 tweet_id           timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56
# 1     892177421306343426 2017-08-01 00:17:27
# 2     891815181378084864 2017-07-31 00:18:03
# 3     891689557279858688 2017-07-30 15:58:51
# 4     891327558926688256 2017-07-29 16:00:24
# 5     891087950875897856 2017-07-29 00:08:17
# 6     890971913173991426 2017-07-28 16:27:12
# 7     890729181411237888 2017-07-28 00:22:40
# 8     890609185150312448 2017-07-27 16:25:51
# 9     890240255349198849 2017-07-26 15:59:51
# 10    890006608113172480 2017-07-26 00:31:25
# 11    889880896479866881 2017-07-25 16:11:53
# 12    889665388333682689 2017-07-25 01:55:32
# 13    889638837579907072 2017-07-25 00:10:02
# 14    889531135344209921 2017-07-24 17:02:04
# 15    889278841981685760 2017-07-24 00:19:32
# 16    888917238123831296 2017-07-23 00:22:39
# 17    888804989199671297 2017-07-22 16:56:37
# 18    888554962724278272 2017-07-22 00:23:06
# 19    888078434458587136 2017-07-20 16:49:33
# ...

# %%
dfmerge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2174
# Data columns (total 11 columns):
# tweet_id              2175 non-null int64
# timestamp             2175 non-null datetime64[ns]
# source                2175 non-null object
# text                  2175 non-null object
# expanded_urls         2117 non-null object
# rating_numerator      2175 non-null int64
# rating_denominator    2175 non-null int64
# name                  2175 non-null object
# dog_stage             344 non-null object
# retweet_count         2175 non-null int64
# favorite_count        2175 non-null int64
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 203.9+ KB

# %%
dfmergefinal=pd.merge(dfmerge1,imagesdf_clean,on='tweet_id',how='inner')

# %%
dfmergefinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 1993
# Data columns (total 22 columns):
# tweet_id              1994 non-null int64
# timestamp             1994 non-null datetime64[ns]
# source                1994 non-null object
# text                  1994 non-null object
# expanded_urls         1994 non-null object
# rating_numerator      1994 non-null int64
# rating_denominator    1994 non-null int64
# name                  1994 non-null object
# dog_stage             306 non-null object
# retweet_count         1994 non-null int64
# favorite_count        1994 non-null int64
# jpg_url               1994 non-null object
# img_num               1994 non-null int64
# p1                    1994 non-null object
# p1_conf               1994 non-null float64
# p1_dog                1994 non-null bool
# p2                    1994 non-null object
# p2_conf               1994 non-null float64
# p2_dog                1994 non-null bool
# ...

# %% [markdown]
# ***Storing Clean dataframe in 'twitter-archive-master.csv'***

# %%
dfmergefinal.to_csv('twitter-archive-master.csv')

# %% [markdown]
# **Analysing and Visualizing**

# %%
dfmergefinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 1993
# Data columns (total 22 columns):
# tweet_id              1994 non-null int64
# timestamp             1994 non-null datetime64[ns]
# source                1994 non-null object
# text                  1994 non-null object
# expanded_urls         1994 non-null object
# rating_numerator      1994 non-null int64
# rating_denominator    1994 non-null int64
# name                  1994 non-null object
# dog_stage             306 non-null object
# retweet_count         1994 non-null int64
# favorite_count        1994 non-null int64
# jpg_url               1994 non-null object
# img_num               1994 non-null int64
# p1                    1994 non-null object
# p1_conf               1994 non-null float64
# p1_dog                1994 non-null bool
# p2                    1994 non-null object
# p2_conf               1994 non-null float64
# p2_dog                1994 non-null bool
# ...

# %%
dfmergefinal.head(2)
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
#
#    rating_denominator     name dog_stage  retweet_count  ...    img_num  \
# 0                  10  Phineas       NaN           8853  ...          1
# 1                  10    Tilly       NaN           6514  ...          1
#
# ...

# %%
dfmergefinal.describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator  retweet_count  \
# count  1.994000e+03       1994.000000              1994.0    1994.000000
# mean   7.358508e+17         10.561685                10.0    2766.753260
# std    6.747816e+16          2.202825                 0.0    4674.698447
# min    6.660209e+17          0.000000                10.0      16.000000
# 25%    6.758475e+17         10.000000                10.0     624.750000
# 50%    7.084748e+17         11.000000                10.0    1359.500000
# 75%    7.877873e+17         12.000000                10.0    3220.000000
# max    8.924206e+17         14.000000                10.0   79515.000000
#
#        favorite_count      img_num      p1_conf       p2_conf       p3_conf
# count     1994.000000  1994.000000  1994.000000  1.994000e+03  1.994000e+03
# mean      8895.725677     1.203109     0.593941  1.344195e-01  6.024848e-02
# std      12213.193181     0.560777     0.271954  1.006807e-01  5.089067e-02
# ...

# %%
# 1) Insight - Highest liked dog breed

# %%
dfmergefinal.favorite_count.max()
# Out:
# 132810

# %%
dfmergefinal[dfmergefinal['favorite_count']== 132810]
# Out:
#                tweet_id           timestamp  \
# 309  822872901745569793 2017-01-21 18:26:02
#
#                                                 source  \
# 309  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  \
# 309  Here's a super supportive puppo participating ...
#
#                                          expanded_urls  rating_numerator  \
# 309  https://twitter.com/dog_rates/status/822872901...                13
#
#      rating_denominator  name dog_stage  retweet_count  ...    img_num  \
# 309                  10  None     puppo          48265  ...          1
#
#                    p1   p1_conf p1_dog                  p2   p2_conf p2_dog  \
# 309  Lakeland_terrier  0.196015   True  Labrador_retriever  0.160329   True
#
#                 p3   p3_conf p3_dog
# 309  Irish_terrier  0.069126   True
#
# [1 rows x 22 columns]

# %%
#Most liked dog is a 'puppo'
#from 'Lakeland_terrier' breed with p1 image prediction

# %%
# 2) Insight - Most given rating

# %%
dfmergefinal['rating_numerator'].value_counts()
# Out:
# 12    450
# 10    419
# 11    396
# 13    280
# 9     151
# 8      95
# 7      52
# 14     35
# 5      33
# 6      32
# 3      19
# 4      16
# 2       9
# 1       5
# 0       2
# Name: rating_numerator, dtype: int64

# %%
# 12 is the most given rating in the numerator with 450 times 
# and second most given is 10

# %%
# 3) Insight - Most tweeted dog stage

# %%
sorted_stage = dfmergefinal['dog_stage'].value_counts().head(3).index
sns.countplot(data = dfmergefinal, x = 'dog_stage')
plt.xlabel('Count')
plt.ylabel('Dog Stages')
plt.title('The Distribution of Dog Stages')
# Out:
# Text(0.5,1,'The Distribution of Dog Stages')

# %%
# Most commonly tweeted dog stage is 'pupper' 
# with approximately 200 instances

# %%
# VISUALIZATION

# %%
dfmergefinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 1993
# Data columns (total 22 columns):
# tweet_id              1994 non-null int64
# timestamp             1994 non-null datetime64[ns]
# source                1994 non-null object
# text                  1994 non-null object
# expanded_urls         1994 non-null object
# rating_numerator      1994 non-null int64
# rating_denominator    1994 non-null int64
# name                  1994 non-null object
# dog_stage             306 non-null object
# retweet_count         1994 non-null int64
# favorite_count        1994 non-null int64
# jpg_url               1994 non-null object
# img_num               1994 non-null int64
# p1                    1994 non-null object
# p1_conf               1994 non-null float64
# p1_dog                1994 non-null bool
# p2                    1994 non-null object
# p2_conf               1994 non-null float64
# p2_dog                1994 non-null bool
# ...

# %%
sns.regplot(x="retweet_count", y="favorite_count", data=dfmergefinal)
plt.title('Correlation plot between retweet and favorite count');

# %%
# Correlation between retweet and favorite count seems to be very high, except few outliers
